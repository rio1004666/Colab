# %% [markdown]
# <a href="https://colab.research.google.com/github/rio1004666/Colab/blob/main/5_%ED%85%8D%EC%8A%A4%ED%8A%B8%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜: 2021/10/18
이름: 강병화
내용: 파이썬 텍스트 시각화 실습 
"""
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image

# %%
# 텍스트 파일 불러오기 
text = open('/content/drive/MyDrive/Colab Notebooks/file/wordcloud_data.txt').read()
text

# %%
# 워드클라우드 출력
wc = WordCloud(width=1200,
               height=1200, 
               font_path='/content/drive/MyDrive/Colab Notebooks/file/malgun.ttf',
               background_color='white').generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.show()
